# %%
import pandas as pd
df = pd.read_csv("../data/processed/clean_data.csv")

# %%
display(df.head())
# Out:
#          ID   Source  Severity           Start_Time             End_Time  \
# 0  A-194257  Source2         3  2016-11-30 16:25:41  2016-11-30 17:10:30
# 1  A-194258  Source2         3  2016-11-30 15:40:06  2016-11-30 17:09:40
# 2  A-194259  Source2         3  2016-11-30 15:26:18  2016-11-30 16:56:02
# 3  A-194260  Source2         3  2016-11-30 16:14:11  2016-11-30 16:59:00
# 4  A-194261  Source2         3  2016-11-30 16:17:57  2016-11-30 17:02:44
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  41.139324 -74.169876      NaN      NaN          0.01  ...      False
# 1  41.118748 -74.159744      NaN      NaN          2.53  ...      False
# 2  41.014034 -73.717239      NaN      NaN          1.17  ...      False
# 3  41.390369 -73.597969      NaN      NaN          0.01  ...      False
# 4  41.390369 -73.597969      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...
